# %% [markdown]
# # Task 1 CNN for Text Classification

# %% [markdown]
# # Introduction

# %% [markdown]
# This part is task 1 of HW3 focusing on the first option: Text Classification. We developed a CNN for the text classification NLP task.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.utils import shuffle

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.optimizers import SGD
from keras.layers import Embedding, Conv1D, Dropout, MaxPooling1D, Flatten, Dense
from keras import regularizers
# Out:
# Using TensorFlow backend.

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## data loading and preprocessing

# %%
df_n = pd.read_table('/Users/jianwenliu/nlp/rt-polaritydata/rt-polaritydata/rt-polarity.neg', names=['review'],  header=None, encoding='latin-1')
df_p = pd.read_table('/Users/jianwenliu/nlp/rt-polaritydata/rt-polaritydata/rt-polarity.pos', names=['review'],  header=None, encoding='latin-1')
# Out:
# /Users/jianwenliu/anaconda3/envs/deepAI/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
# /Users/jianwenliu/anaconda3/envs/deepAI/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.

# %%
df_n.head(10)
# Out:
#                                               review
# 0                  simplistic , silly and tedious .
# 1  it's so laddish and juvenile , only teenage bo...
# 2  exploitative and largely devoid of the depth o...
# 3  [garbus] discards the potential for pathologic...
# 4  a visually flashy but narratively opaque and e...
# 5  the story is also as unoriginal as they come ,...
# 6  about the only thing to give the movie points ...
# 7                    not so much farcical as sour .
# 8  unfortunately the story and the actors are ser...
# 9  all the more disquieting for its relatively go...

# %% [markdown]
# label the review with 0 and 1

# %%
df_n['lable'] = 0
df_p['lable'] = 1

# %% [markdown]
# Concate and shuffle the dataset, making it 50-50

# %%
df = shuffle(pd.concat((df_n, df_p), axis=0), random_state=7)

# %%
df
# Out:
#                                                  review  lable
# 1777  this is an egotistical endeavor from the daugh...      0
# 2272  where last time jokes flowed out of cho's life...      0
# 155   everything that has to do with yvan and charlo...      1
# 4137  an affectionately goofy satire that's unafraid...      1
# 2428  i was impressed by how many tit-for-tat retali...      1
# 3039  what [denis] accomplishes in his chilling , un...      1
# 2411  a journey that's too random and inconclusive t...      0
# 3626  promises is one film that's truly deserving of...      1
# 2463  all this turns out to be neither funny nor pro...      0
# 2302  the stripped-down dramatic constructs , auster...      1
# 2896  even as it pays earnest homage to turntablists...      1
# 2786  the scorpion king is more fun than conan the b...      1
# 1331  there is a fabric of complex ideas here , and ...      1
# 1685  in exactly 89 minutes , most of which passed a...      0
# 3236  too many scenarios in which the hero might hav...      0
# 571   a seriously bad film with seriously warped log...      0
# 4706  don't wait to see this terrific film with your...      1
# 1926  uplifting as only a document of the worst poss...      1
# 4164  the movie is like scorsese's mean streets redo...      0
# 4426  the pretensions -- and disposable story -- sin...      0
# 675   the re- enactments , however fascinating they ...      0
# 3352  be forewarned , if you're depressed about anyt...      0
# 5157  has enough wit , energy and geniality to pleas...      1
# 2443  matthew mcconaughey tries , and fails , to con...      0
# 349   over-the-top and a bit ostentatious , this is ...      1
# 4445  been there , done that . . . a thousand times ...      0
# 2021  even horror fans will most likely not find wha...      0
# 2759  one of those unassuming films that sneaks up o...      1
# 3357  daughter from danang reveals that efforts towa...      1
# 2237  a raunchy and frequently hilarious follow-up t...      1
# ...                                                 ...    ...
# 2320  if cinema had been around to capture the chaos...      1
# 4022                 a small movie with a big impact .       1
# 3633  [it's] a clever thriller with enough unexpecte...      1
# 251   one of the greatest romantic comedies of the p...      1
# 3173  if you ever wondered what it would be like to ...      1
# 4859  don michael paul uses quick-cuts , ( very ) la...      0
# 2997  flotsam in the sea of moviemaking , not big en...      0
# 1176  the only way to tolerate this insipid , brutal...      0
# 3896  there ain't a lot more painful than an unfunny...      0
# 4210  a treat for its depiction on not giving up on ...      1
# 3516  the filmmakers needed more emphasis on the sto...      0
# 2624  very well written and directed with brutal hon...      1
# 5159  bittersweet comedy/drama full of life , hand g...      1
# 2349  it ain't art , by a long shot , but unlike las...      1
# 1753  s1m0ne's satire is not subtle , but it is effe...      1
# 3252  the film is about the relationships rather tha...      1
# 684   the movie sticks much closer to hornby's drop-...      1
# 1456  seems like something american and european gay...      0
# 1092  gibney and jarecki just want to string the bas...      0
# 787   that rara avis : the intelligent romantic come...      1
# 3239  broomfield's style of journalism is hardly jou...      0
# 4441  showtime isn't particularly assaultive , but i...      0
# 2583  an overstuffed compendium of teen-catholic-mov...      0
# 2235  amazing ! a college story that works even with...      1
# 1372  so boring that even its target audience talked...      0
# 919   nothing more than an amiable but unfocused bag...      0
# 4307  every joke is repeated at least four times . e...      0
# 368   by the end of no such thing the audience , lik...      1
# 537   a 75-minute sample of puerile rubbish that is ...      0
# 4081  i'd watch these two together again in a new yo...      1
#
# [10662 rows x 2 columns]

# %%
df.shape
# Out:
# (10662, 2)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['review'])

# %%
sequences = tokenizer.texts_to_sequences(df['review'])

# %%
max_len = max([len(seq) for seq in sequences])
max_len
# Out:
# 51

# %% [markdown]
# Padding the sequences

# %%
sequences = pad_sequences(sequences, maxlen=max_len, dtype='int32', padding='pre', truncating='pre', value=0)

# %%
sequences
# Out:
# array([[   0,    0,    0, ...,    9, 1022, 4625],
#        [   0,    0,    0, ..., 1074, 1023, 3890],
#        [   0,    0,    0, ...,   64,    3,  281],
#        ...,
#        [   0,    0,    0, ...,   14,    1,  941],
#        [   0,    0,    0, ...,  282, 4424,  147],
#        [   0,    0,    0, ...,   93, 1003,  369]], dtype=int32)

# %% [markdown]
# get thr dictionaty for the word index

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'a': 2,
#  'and': 3,
#  'of': 4,
#  'to': 5,
#  'is': 6,
#  'in': 7,
#  'that': 8,
#  'it': 9,
#  'as': 10,
#  'but': 11,
#  'with': 12,
#  'film': 13,
#  'for': 14,
#  'this': 15,
#  'its': 16,
#  'an': 17,
#  'movie': 18,
#  "it's": 19,
#  'be': 20,
#  'on': 21,
#  'you': 22,
#  'not': 23,
#  'by': 24,
#  'one': 25,
#  'like': 26,
#  'about': 27,
#  'more': 28,
#  'has': 29,
#  'are': 30,
#  'at': 31,
#  'than': 32,
#  'from': 33,
#  'all': 34,
#  'his': 35,
#  'have': 36,
#  'so': 37,
#  'if': 38,
#  'or': 39,
#  'story': 40,
#  'too': 41,
#  'i': 42,
#  'out': 43,
#  'just': 44,
#  'who': 45,
#  'up': 46,
#  'good': 47,
#  'into': 48,
#  'what': 49,
#  'most': 50,
#  'no': 51,
#  'much': 52,
#  'even': 53,
#  'comedy': 54,
#  'time': 55,
#  'will': 56,
#  'can': 57,
#  'some': 58,
#  'well': 59,
#  'characters': 60,
#  'only': 61,
#  'little': 62,
#  'way': 63,
#  'funny': 64,
#  'their': 65,
#  'director': 66,
#  'make': 67,
#  'been': 68,
#  'your': 69,
#  'enough': 70,
#  'very': 71,
#  'never': 72,
#  'when': 73,
#  'there': 74,
#  'makes': 75,
#  'life': 76,
#  'bad': 77,
#  'may': 78,
#  'which': 79,
#  'us': 80,
#  'best': 81,
#  'work': 82,
#  'he': 83,
#  "doesn't": 84,
#  'love': 85,
#  'any': 86,
#  'would': 87,
#  'made': 88,
#  'while': 89,
#  'they': 90,
#  'we': 91,
#  'was': 92,
#  'new': 93,
#  "there's": 94,
#  'movies': 95,
#  'her': 96,
#  'off': 97,
#  'through': 98,
#  'something': 99,
#  'could': 100,
#  'how': 101,
#  'action': 102,
#  'really': 103,
#  'drama': 104,
#  'two': 105,
#  'them': 106,
#  'see': 107,
#  'own': 108,
#  'does': 109,
#  'performances': 110,
#  "that's": 111,
#  'many': 112,
#  'long': 113,
#  'should': 114,
#  'those': 115,
#  'still': 116,
#  'plot': 117,
#  'look': 118,
#  'films': 119,
#  'every': 120,
#  "isn't": 121,
#  'over': 122,
#  'old': 123,
#  'big': 124,
#  'first': 125,
#  'nothing': 126,
#  'better': 127,
#  'people': 128,
#  'fun': 129,
#  'get': 130,
#  'without': 131,
#  'other': 132,
#  'great': 133,
#  'being': 134,
#  'both': 135,
#  'though': 136,
#  'might': 137,
#  "'": 138,
#  'character': 139,
#  'do': 140,
#  'also': 141,
#  'another': 142,
#  'cast': 143,
#  'real': 144,
#  'kind': 145,
#  'audience': 146,
#  'humor': 147,
#  'ever': 148,
#  'between': 149,
#  'self': 150,
#  'sense': 151,
#  'feel': 152,
#  'such': 153,
#  'less': 154,
#  "don't": 155,
#  'down': 156,
#  'often': 157,
#  'far': 158,
#  'performance': 159,
#  'feels': 160,
#  'few': 161,
#  'hard': 162,
#  'script': 163,
#  'because': 164,
#  "film's": 165,
#  'screen': 166,
#  'world': 167,
#  'here': 168,
#  'thriller': 169,
#  'thing': 170,
#  'seems': 171,
#  'minutes': 172,
#  'tale': 173,
#  'full': 174,
#  'quite': 175,
#  'heart': 176,
#  'picture': 177,
#  'documentary': 178,
#  'almost': 179,
#  "can't": 180,
#  'end': 181,
#  'hollywood': 182,
#  'yet': 183,
#  'interesting': 184,
#  'after': 185,
#  'entertaining': 186,
#  'go': 187,
#  'these': 188,
#  'american': 189,
#  "you're": 190,
#  'my': 191,
#  'rather': 192,
#  'year': 193,
#  'take': 194,
#  'itself': 195,
#  'de': 196,
#  'watching': 197,
#  'seen': 198,
#  'ultimately': 199,
#  'man': 200,
#  'romantic': 201,
#  'family': 202,
#  'comes': 203,
#  'moments': 204,
#  'me': 205,
#  'lot': 206,
#  'right': 207,
#  'despite': 208,
#  'were': 209,
#  'where': 210,
#  'original': 211,
#  'acting': 212,
#  'before': 213,
#  'human': 214,
#  'had': 215,
#  'then': 216,
#  'same': 217,
#  'find': 218,
#  'worth': 219,
#  'gets': 220,
#  'times': 221,
#  'takes': 222,
#  'back': 223,
#  'things': 224,
#  'come': 225,
#  'dialogue': 226,
#  'actors': 227,
#  'scenes': 228,
#  'watch': 229,
#  'high': 230,
#  'compelling': 231,
#  'our': 232,
#  'material': 233,
#  'young': 234,
#  'once': 235,
#  'years': 236,
#  'music': 237,
#  'style': 238,
#  'going': 239,
#  'half': 240,
#  'works': 241,
#  'think': 242,
#  'star': 243,
#  'know': 244,
#  'want': 245,
#  'seem': 246,
#  'emotional': 247,
#  'least': 248,
#  'anyone': 249,
#  'last': 250,
#  'point': 251,
#  'gives': 252,
#  'special': 253,
#  'piece': 254,
#  'kids': 255,
#  'making': 256,
#  'part': 257,
#  'say': 258,
#  'give': 259,
#  'again': 260,
#  'writer': 261,
#  'sometimes': 262,
#  'cinematic': 263,
#  'together': 264,
#  'pretty': 265,
#  'entertainment': 266,
#  'subject': 267,
#  'cinema': 268,
#  'show': 269,
#  'moving': 270,
#  "you'll": 271,
#  'bit': 272,
#  'video': 273,
#  'keep': 274,
#  'dull': 275,
#  'whole': 276,
#  'fascinating': 277,
#  'fans': 278,
#  'why': 279,
#  'sweet': 280,
#  'true': 281,
#  'anything': 282,
#  'war': 283,
#  'away': 284,
#  'art': 285,
#  'age': 286,
#  'since': 287,
#  'need': 288,
#  'manages': 289,
#  'laughs': 290,
#  'flick': 291,
#  'history': 292,
#  'dark': 293,
#  'clever': 294,
#  'experience': 295,
#  'three': 296,
#  'offers': 297,
#  'always': 298,
#  'silly': 299,
#  'direction': 300,
#  'simply': 301,
#  'low': 302,
#  'predictable': 303,
#  'mr': 304,
#  'day': 305,
#  'comic': 306,
#  'feature': 307,
#  'instead': 308,
#  'whose': 309,
#  'done': 310,
#  'charm': 311,
#  'nearly': 312,
#  'actually': 313,
#  'around': 314,
#  'care': 315,
#  'him': 316,
#  'coming': 317,
#  'horror': 318,
#  'everything': 319,
#  'title': 320,
#  'matter': 321,
#  'under': 322,
#  'visual': 323,
#  'series': 324,
#  'place': 325,
#  'familiar': 326,
#  'narrative': 327,
#  'looking': 328,
#  'idea': 329,
#  "he's": 330,
#  'genre': 331,
#  'effects': 332,
#  'set': 333,
#  'short': 334,
#  'screenplay': 335,
#  'trying': 336,
#  'now': 337,
#  'mind': 338,
#  'goes': 339,
#  'women': 340,
#  'plays': 341,
#  'smart': 342,
#  "movie's": 343,
#  'probably': 344,
#  'power': 345,
#  'premise': 346,
#  'home': 347,
#  'hour': 348,
#  'turns': 349,
#  'she': 350,
#  'thought': 351,
#  'enjoyable': 352,
#  'filmmakers': 353,
#  'lacks': 354,
#  'although': 355,
#  'engaging': 356,
#  'feeling': 357,
#  'becomes': 358,
#  'worst': 359,
#  'especially': 360,
#  'study': 361,
#  "won't": 362,
#  'amusing': 363,
#  'strong': 364,
#  'enjoy': 365,
#  'ending': 366,
#  'likely': 367,
#  'intelligent': 368,
#  'minute': 369,
#  'lack': 370,
#  'romance': 371,
#  'charming': 372,
#  'modern': 373,
#  'effort': 374,
#  'face': 375,
#  'boring': 376,
#  'tv': 377,
#  'john': 378,
#  'directed': 379,
#  'debut': 380,
#  'acted': 381,
#  'men': 382,
#  'theater': 383,
#  'solid': 384,
#  'put': 385,
#  'portrait': 386,
#  'fresh': 387,
#  'mostly': 388,
#  'else': 389,
#  'each': 390,
#  'wit': 391,
#  'girl': 392,
#  'hours': 393,
#  'version': 394,
#  'beautiful': 395,
#  'sort': 396,
#  'shot': 397,
#  "what's": 398,
#  'certainly': 399,
#  'easy': 400,
#  'message': 401,
#  'level': 402,
#  'beautifully': 403,
#  "you've": 404,
#  'serious': 405,
#  'next': 406,
#  'heavy': 407,
#  'play': 408,
#  'fine': 409,
#  'become': 410,
#  'surprisingly': 411,
#  'black': 412,
#  'lives': 413,
#  'energy': 414,
#  'quirky': 415,
#  'sure': 416,
#  'along': 417,
#  'slow': 418,
#  'rare': 419,
#  'interest': 420,
#  'french': 421,
#  'problem': 422,
#  'small': 423,
#  'light': 424,
#  'exercise': 425,
#  'obvious': 426,
#  'ideas': 427,
#  'leave': 428,
#  'looks': 429,
#  'whether': 430,
#  'beyond': 431,
#  'mess': 432,
#  'powerful': 433,
#  'dramatic': 434,
#  'either': 435,
#  'fact': 436,
#  'opera': 437,
#  'culture': 438,
#  'must': 439,
#  'past': 440,
#  'melodrama': 441,
#  'completely': 442,
#  'neither': 443,
#  'actor': 444,
#  'reason': 445,
#  'believe': 446,
#  'book': 447,
#  'classic': 448,
#  'children': 449,
#  'tone': 450,
#  'adventure': 451,
#  'viewers': 452,
#  'jokes': 453,
#  'fails': 454,
#  "i'm": 455,
#  'recent': 456,
#  'suspense': 457,
#  'live': 458,
#  'school': 459,
#  'shows': 460,
#  'death': 461,
#  'written': 462,
#  'sex': 463,
#  'delivers': 464,
#  'stuff': 465,
#  'filmmaking': 466,
#  "didn't": 467,
#  'truly': 468,
#  'tries': 469,
#  'left': 470,
#  'camera': 471,
#  'intriguing': 472,
#  'everyone': 473,
#  'production': 474,
#  'deeply': 475,
#  'scene': 476,
#  'perfect': 477,
#  'ends': 478,
#  'middle': 479,
#  'himself': 480,
#  'laugh': 481,
#  'ride': 482,
#  'sad': 483,
#  'spirit': 484,
#  'above': 485,
#  'close': 486,
#  'head': 487,
#  'simple': 488,
#  'line': 489,
#  'exactly': 490,
#  'hilarious': 491,
#  'reality': 492,
#  'impossible': 493,
#  'touching': 494,
#  'occasionally': 495,
#  'dumb': 496,
#  'audiences': 497,
#  'formula': 498,
#  'terrific': 499,
#  'already': 500,
#  'remains': 501,
#  'proves': 502,
#  'passion': 503,
#  'spy': 504,
#  'satisfying': 505,
#  'role': 506,
#  'storytelling': 507,
#  'nor': 508,
#  'got': 509,
#  'pleasure': 510,
#  'images': 511,
#  'dead': 512,
#  'seeing': 513,
#  'project': 514,
#  'filmmaker': 515,
#  'b': 516,
#  'talent': 517,
#  'different': 518,
#  'crime': 519,
#  'stories': 520,
#  'summer': 521,
#  'teen': 522,
#  'journey': 523,
#  'turn': 524,
#  'side': 525,
#  'political': 526,
#  'particularly': 527,
#  'run': 528,
#  'sequel': 529,
#  'easily': 530,
#  'gags': 531,
#  'personal': 532,
#  'flat': 533,
#  'attempt': 534,
#  'complex': 535,
#  'difficult': 536,
#  'boy': 537,
#  'honest': 538,
#  'given': 539,
#  'pretentious': 540,
#  'mystery': 541,
#  'against': 542,
#  'animation': 543,
#  'psychological': 544,
#  'earnest': 545,
#  'stand': 546,
#  'cold': 547,
#  'second': 548,
#  'social': 549,
#  'visually': 550,
#  'cool': 551,
#  'did': 552,
#  'falls': 553,
#  'case': 554,
#  'found': 555,
#  'intelligence': 556,
#  'thin': 557,
#  'michael': 558,
#  'ways': 559,
#  'none': 560,
#  'class': 561,
#  'eye': 562,
#  'gone': 563,
#  'getting': 564,
#  'tell': 565,
#  'told': 566,
#  'straight': 567,
#  'hit': 568,
#  'cliches': 569,
#  'game': 570,
#  'leaves': 571,
#  'top': 572,
#  'writing': 573,
#  'brilliant': 574,
#  'memorable': 575,
#  'uses': 576,
#  'budget': 577,
#  'help': 578,
#  'violence': 579,
#  'que': 580,
#  'satire': 581,
#  'soap': 582,
#  'job': 583,
#  'overall': 584,
#  'act': 585,
#  'finally': 586,
#  'four': 587,
#  'keeps': 588,
#  'rock': 589,
#  'truth': 590,
#  'concept': 591,
#  'novel': 592,
#  'wrong': 593,
#  'rich': 594,
#  'elements': 595,
#  'barely': 596,
#  'otherwise': 597,
#  'needs': 598,
#  'deep': 599,
#  'contrived': 600,
#  '2': 601,
#  'warm': 602,
#  'rarely': 603,
#  'o': 604,
#  'nature': 605,
#  'guys': 606,
#  'creepy': 607,
#  'lost': 608,
#  'days': 609,
#  'worthy': 610,
#  'important': 611,
#  'disney': 612,
#  'possible': 613,
#  'thoughtful': 614,
#  'wild': 615,
#  'form': 616,
#  'taste': 617,
#  'starts': 618,
#  'clear': 619,
#  'mood': 620,
#  'entirely': 621,
#  'fi': 622,
#  'running': 623,
#  'final': 624,
#  'y': 625,
#  'during': 626,
#  'appeal': 627,
#  'approach': 628,
#  'having': 629,
#  'moral': 630,
#  'imagine': 631,
#  'several': 632,
#  'behind': 633,
#  'oscar': 634,
#  "they're": 635,
#  'surprising': 636,
#  'future': 637,
#  'eyes': 638,
#  'wonderful': 639,
#  'animated': 640,
#  'fairly': 641,
#  'city': 642,
#  'lead': 643,
#  '\x96': 644,
#  'excellent': 645,
#  'adults': 646,
#  'sci': 647,
#  'perhaps': 648,
#  'loud': 649,
#  'tragedy': 650,
#  'insight': 651,
#  'fire': 652,
#  'based': 653,
#  'attention': 654,
#  'call': 655,
#  'engrossing': 656,
#  'hero': 657,
#  'among': 658,
#  'quality': 659,
#  'entire': 660,
#  'imagination': 661,
#  'period': 662,
#  'thoroughly': 663,
#  'bland': 664,
#  'bring': 665,
#  'viewer': 666,
#  'comedies': 667,
#  'remarkable': 668,
#  'change': 669,
#  'witty': 670,
#  'start': 671,
#  'others': 672,
#  'epic': 673,
#  'tedious': 674,
#  'fantasy': 675,
#  'depth': 676,
#  'david': 677,
#  'woman': 678,
#  'expect': 679,
#  'moment': 680,
#  'cute': 681,
#  'themselves': 682,
#  'result': 683,
#  'taking': 684,
#  'wonder': 685,
#  'remake': 686,
#  'road': 687,
#  'house': 688,
#  'vision': 689,
#  'merely': 690,
#  'single': 691,
#  'air': 692,
#  'nice': 693,
#  'hand': 694,
#  'perfectly': 695,
#  'cut': 696,
#  'sharp': 697,
#  'genuine': 698,
#  'adaptation': 699,
#  'add': 700,
#  'latest': 701,
#  'knows': 702,
#  'quiet': 703,
#  'pop': 704,
#  'gorgeous': 705,
#  "i've": 706,
#  'tired': 707,
#  'emotionally': 708,
#  'working': 709,
#  'career': 710,
#  'maybe': 711,
#  'filled': 712,
#  'la': 713,
#  'fast': 714,
#  'co': 715,
#  "you'd": 716,
#  'usual': 717,
#  'strange': 718,
#  'surprise': 719,
#  'joke': 720,
#  'cultural': 721,
#  'scary': 722,
#  'events': 723,
#  'points': 724,
#  'view': 725,
#  'parents': 726,
#  'impressive': 727,
#  'stupid': 728,
#  'somewhat': 729,
#  'appealing': 730,
#  'decent': 731,
#  'guy': 732,
#  'thanks': 733,
#  'beauty': 734,
#  'ugly': 735,
#  'gentle': 736,
#  'white': 737,
#  'offer': 738,
#  'cheap': 739,
#  'winning': 740,
#  'hope': 741,
#  'begins': 742,
#  'doing': 743,
#  'plenty': 744,
#  'effective': 745,
#  'until': 746,
#  'worse': 747,
#  'ii': 748,
#  'mean': 749,
#  'someone': 750,
#  'however': 751,
#  'provides': 752,
#  'emotions': 753,
#  'playing': 754,
#  'lots': 755,
#  'definitely': 756,
#  'inside': 757,
#  'miss': 758,
#  'captures': 759,
#  'pure': 760,
#  'water': 761,
#  'try': 762,
#  'sit': 763,
#  'magic': 764,
#  'unfortunately': 765,
#  'awful': 766,
#  'highly': 767,
#  "year's": 768,
#  'able': 769,
#  'ambitious': 770,
#  'open': 771,
#  'major': 772,
#  'sound': 773,
#  'stars': 774,
#  'utterly': 775,
#  'examination': 776,
#  'night': 777,
#  'free': 778,
#  'pace': 779,
#  'pictures': 780,
#  'welcome': 781,
#  'suffers': 782,
#  'robert': 783,
#  'subtle': 784,
#  'sequences': 785,
#  'execution': 786,
#  'throughout': 787,
#  'brings': 788,
#  'historical': 789,
#  'exciting': 790,
#  'force': 791,
#  'hip': 792,
#  'female': 793,
#  'crafted': 794,
#  'provocative': 795,
#  'deserves': 796,
#  'murder': 797,
#  'numbers': 798,
#  'hell': 799,
#  'soul': 800,
#  'read': 801,
#  'lovely': 802,
#  'certain': 803,
#  'sexual': 804,
#  '90': 805,
#  'college': 806,
#  'creative': 807,
#  'fashioned': 808,
#  'relationship': 809,
#  'meaning': 810,
#  'memory': 811,
#  'sustain': 812,
#  'process': 813,
#  'felt': 814,
#  'alone': 815,
#  'ensemble': 816,
#  'country': 817,
#  'impact': 818,
#  'actress': 819,
#  'delightful': 820,
#  'dog': 821,
#  'flaws': 822,
#  'poignant': 823,
#  'across': 824,
#  'era': 825,
#  'ago': 826,
#  'wants': 827,
#  'chemistry': 828,
#  'average': 829,
#  'bond': 830,
#  'used': 831,
#  'tension': 832,
#  'odd': 833,
#  'e': 834,
#  'potential': 835,
#  'deal': 836,
#  'cartoon': 837,
#  'quickly': 838,
#  'question': 839,
#  'ya': 840,
#  'creates': 841,
#  'paced': 842,
#  'use': 843,
#  'length': 844,
#  'words': 845,
#  'except': 846,
#  'upon': 847,
#  'unsettling': 848,
#  'success': 849,
#  't': 850,
#  'formulaic': 851,
#  'trip': 852,
#  'lacking': 853,
#  'rest': 854,
#  'money': 855,
#  'flawed': 856,
#  'puts': 857,
#  'generic': 858,
#  'yes': 859,
#  'contemporary': 860,
#  'talented': 861,
#  'extreme': 862,
#  'touch': 863,
#  'date': 864,
#  'situation': 865,
#  'create': 866,
#  'happy': 867,
#  'issues': 868,
#  'five': 869,
#  'master': 870,
#  'mediocre': 871,
#  'called': 872,
#  'sensitive': 873,
#  'sentimental': 874,
#  'handed': 875,
#  'unfunny': 876,
#  'unexpected': 877,
#  'waste': 878,
#  'casting': 879,
#  'taken': 880,
#  'seriously': 881,
#  'trouble': 882,
#  'reveals': 883,
#  'relationships': 884,
#  'boys': 885,
#  'cannot': 886,
#  'crowd': 887,
#  'badly': 888,
#  'weird': 889,
#  "aren't": 890,
#  'remember': 891,
#  'forgettable': 892,
#  'urban': 893,
#  'involved': 894,
#  'focus': 895,
#  'sincere': 896,
#  'mildly': 897,
#  's': 898,
#  'leads': 899,
#  'course': 900,
#  'previous': 901,
#  'extremely': 902,
#  'saw': 903,
#  'melodramatic': 904,
#  'slightly': 905,
#  'hardly': 906,
#  'convincing': 907,
#  'episode': 908,
#  'artist': 909,
#  'watchable': 910,
#  'thinking': 911,
#  'fully': 912,
#  'ability': 913,
#  'mark': 914,
#  'living': 915,
#  'ultimate': 916,
#  'routine': 917,
#  'surprises': 918,
#  'hold': 919,
#  'mix': 920,
#  'key': 921,
#  'inspired': 922,
#  'masterpiece': 923,
#  'apart': 924,
#  'giving': 925,
#  'supposed': 926,
#  'grace': 927,
#  'large': 928,
#  'grant': 929,
#  'yourself': 930,
#  'substance': 931,
#  'thrills': 932,
#  'george': 933,
#  'room': 934,
#  'succeeds': 935,
#  'provoking': 936,
#  'ill': 937,
#  'ones': 938,
#  'kid': 939,
#  'largely': 940,
#  'monster': 941,
#  'stylish': 942,
#  'indeed': 943,
#  'intimate': 944,
#  'sets': 945,
#  'tragic': 946,
#  'amount': 947,
#  'name': 948,
#  'crazy': 949,
#  'dry': 950,
#  'inventive': 951,
#  'uneven': 952,
#  'finds': 953,
#  'pacing': 954,
#  'gross': 955,
#  'slight': 956,
#  'gripping': 957,
#  'couple': 958,
#  'treat': 959,
#  'crush': 960,
#  'pleasant': 961,
#  'steven': 962,
#  'plain': 963,
#  'century': 964,
#  'twists': 965,
#  'terms': 966,
#  'attempts': 967,
#  'goofy': 968,
#  'poetry': 969,
#  'interested': 970,
#  'happens': 971,
#  'hits': 972,
#  'meditation': 973,
#  '10': 974,
#  'business': 975,
#  'heaven': 976,
#  'skin': 977,
#  'themes': 978,
#  'problems': 979,
#  'near': 980,
#  'involving': 981,
#  'lame': 982,
#  'gay': 983,
#  'bright': 984,
#  'painful': 985,
#  "we've": 986,
#  'missing': 987,
#  'indulgent': 988,
#  'played': 989,
#  'viewing': 990,
#  'unique': 991,
#  "she's": 992,
#  'cross': 993,
#  'television': 994,
#  'es': 995,
#  'considerable': 996,
#  'absolutely': 997,
#  'word': 998,
#  'edge': 999,
#  'presents': 1000,
#  ...}

# %% [markdown]
# get the voc size

# %%
voc_size=len(tokenizer.word_index)

# %%
voc_size
# Out:
# 19498

# %% [markdown]
# ## CNN model

# %% [markdown]
# Build the CNN model

# %%
def conv_model(output_dim=64, filter_size=128, window_size=3, stride=1, pool_size=2, dense_dim=16):

    model = Sequential()
    model.add(Embedding(voc_size+1, output_dim, input_length=max_len, embeddings_initializer='random_uniform'))
    
    # conv1D, same padding
    model.add(Conv1D(filter_size, kernel_size=(output_dim*window_size),padding='same', strides=(stride), activation='relu'))
    
    #dropout1
    model.add(Dropout(0.6))
    
    #pooling
    model.add(MaxPooling1D(pool_size=(pool_size), padding='same'))
    
    # flatten
    model.add(Flatten())
    
    # fully connected layer
    model.add(Dense(dense_dim,activation='relu'))
    
    #dropout2
    model.add(Dropout(0.6))
    
    # output layer
    model.add(Dense(1, kernel_regularizer=regularizers.l2(0.01),activity_regularizer=regularizers.l1(0.01),activation='sigmoid'))
    
    #use rmsprop
    model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    
    return model
    
conv_model().summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 51, 64)            1247936
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 51, 128)           1572992
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 51, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 26, 128)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3328)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                53264
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 2,874,209
# Trainable params: 2,874,209
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 10
BATCH_SIZE = 128
fold = 8

model = conv_model()
X = sequences
y = np.array(df.lable.tolist())

# %% [markdown]
# K-Fold for validation

# %%
kfold = StratifiedKFold(n_splits=fold, shuffle=True, random_state=7)

# %% [markdown]
# ## Model performance : prediction accuracy

# %%
acr = list()
i = 0

#validation
for train_index, valid_index in kfold.split(X, y):
    i += 1
    X_train, X_valid = X[train_index], X[valid_index]
    y_train, y_valid = y[train_index], y[valid_index]
    
    #model
    model = conv_model()
    model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=2, validation_data=(X_valid, y_valid),callbacks=[EarlyStopping(patience=1, monitor='val_loss')])
    
    #prediction
    y_bar = model.predict(X_valid)
    y_pred = [round(pred) for pred in y_bar.reshape(-1)]
    
    #accuracy
    acr.append(accuracy_score(y_valid, y_pred))
# Out:
# Train on 9328 samples, validate on 1334 samples
# Epoch 1/10
#  - 106s - loss: 1.2014 - acc: 0.4994 - val_loss: 1.0976 - val_acc: 0.5000
# Epoch 2/10
#  - 104s - loss: 1.0123 - acc: 0.6307 - val_loss: 1.0101 - val_acc: 0.7324
# Epoch 3/10
#  - 110s - loss: 0.8693 - acc: 0.8201 - val_loss: 0.9833 - val_acc: 0.7459
# Epoch 4/10
#  - 108s - loss: 0.7825 - acc: 0.8814 - val_loss: 1.0180 - val_acc: 0.7564
# Train on 9328 samples, validate on 1334 samples
# Epoch 1/10
#  - 101s - loss: 1.1940 - acc: 0.4994 - val_loss: 1.0855 - val_acc: 0.5000
# Epoch 2/10
#  - 100s - loss: 0.9795 - acc: 0.6946 - val_loss: 1.0306 - val_acc: 0.6829
# Epoch 3/10
#  - 104s - loss: 0.8539 - acc: 0.8406 - val_loss: 1.0592 - val_acc: 0.7429
# Train on 9328 samples, validate on 1334 samples
# Epoch 1/10
#  - 101s - loss: 1.2376 - acc: 0.4994 - val_loss: 1.1734 - val_acc: 0.5000
# Epoch 2/10
#  - 107s - loss: 1.0678 - acc: 0.5846 - val_loss: 1.0767 - val_acc: 0.7009
# Epoch 3/10
#  - 106s - loss: 0.9192 - acc: 0.8095 - val_loss: 1.0302 - val_acc: 0.7346
# Epoch 4/10
#  - 103s - loss: 0.8367 - acc: 0.8732 - val_loss: 1.0440 - val_acc: 0.7301
# Train on 9330 samples, validate on 1332 samples
# Epoch 1/10
#  - 141s - loss: 1.2230 - acc: 0.5023 - val_loss: 1.1858 - val_acc: 0.5000
# Epoch 2/10
#  - 136s - loss: 1.0201 - acc: 0.6387 - val_loss: 1.0420 - val_acc: 0.6787
# Epoch 3/10
#  - 144s - loss: 0.8833 - acc: 0.8190 - val_loss: 1.0345 - val_acc: 0.7230
# Epoch 4/10
#  - 129s - loss: 0.7886 - acc: 0.8855 - val_loss: 1.0688 - val_acc: 0.7410
# Train on 9330 samples, validate on 1332 samples
# Epoch 1/10
#  - 120s - loss: 1.2076 - acc: 0.5027 - val_loss: 1.1259 - val_acc: 0.5000
# Epoch 2/10
#  - 120s - loss: 1.0147 - acc: 0.6779 - val_loss: 1.0420 - val_acc: 0.7350
# Epoch 3/10
#  - 121s - loss: 0.8770 - acc: 0.8325 - val_loss: 1.0167 - val_acc: 0.7267
# Epoch 4/10
#  - 129s - loss: 0.7913 - acc: 0.8980 - val_loss: 1.0486 - val_acc: 0.7275
# Train on 9330 samples, validate on 1332 samples
# Epoch 1/10
#  - 119s - loss: 1.2239 - acc: 0.4998 - val_loss: 1.1358 - val_acc: 0.5000
# Epoch 2/10
#  - 131s - loss: 1.0604 - acc: 0.6079 - val_loss: 1.0776 - val_acc: 0.7380
# Epoch 3/10
#  - 129s - loss: 0.9111 - acc: 0.8090 - val_loss: 1.0078 - val_acc: 0.7320
# Epoch 4/10
#  - 135s - loss: 0.8248 - acc: 0.8875 - val_loss: 1.0228 - val_acc: 0.7470
# Train on 9330 samples, validate on 1332 samples
# Epoch 1/10
#  - 138s - loss: 1.2128 - acc: 0.4986 - val_loss: 1.1156 - val_acc: 0.5000
# Epoch 2/10
#  - 117s - loss: 1.0248 - acc: 0.6006 - val_loss: 1.0074 - val_acc: 0.6809
# Epoch 3/10
#  - 114s - loss: 0.8831 - acc: 0.7707 - val_loss: 0.9941 - val_acc: 0.7342
# Epoch 4/10
#  - 110s - loss: 0.7923 - acc: 0.8217 - val_loss: 1.0073 - val_acc: 0.7650
# Train on 9330 samples, validate on 1332 samples
# Epoch 1/10
#  - 106s - loss: 1.2452 - acc: 0.5003 - val_loss: 1.1402 - val_acc: 0.5000
# Epoch 2/10
#  - 108s - loss: 1.0411 - acc: 0.5758 - val_loss: 1.0097 - val_acc: 0.6562
# Epoch 3/10
#  - 109s - loss: 0.8852 - acc: 0.7923 - val_loss: 1.0035 - val_acc: 0.7357
# Epoch 4/10
#  - 108s - loss: 0.7926 - acc: 0.8563 - val_loss: 1.0332 - val_acc: 0.7365

# %%
print('Average accuracy ', np.mean(np.array(acr)))
# Out:
# Average accuracy  0.7432940342891616

# %% [markdown]
# # Conclusion

# %% [markdown]
# We can find out from the accuracy that CNN has a acceptable prediction performance, reaching 0.74. However, the speed to train the CNN model is so slow which takes 110s for each epoch. In practice, this will be a obvious drawback.
