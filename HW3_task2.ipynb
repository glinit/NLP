# %% [markdown]
# # Task 2 RNN for Text Classification

# %% [markdown]
# # Introduction

# %% [markdown]
# This part is task 2 of HW3 focusing on the RNN: Text Classification. We developed a RNN model, specifically a LSTM model, for the text classification NLP task. The last part of this task is to compare RNN and CNN in the same task.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.utils import shuffle

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.optimizers import SGD
from keras.layers import Embedding, Conv1D, Dropout, MaxPooling1D, Flatten, Dense
from keras import regularizers

# %%
from keras.models import Model
from keras.optimizers import SGD
from keras.layers import Input, Embedding, LSTM, Dropout, Bidirectional, Dense, Flatten
from keras import regularizers

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
df_n = pd.read_table('/Users/jianwenliu/nlp/rt-polaritydata/rt-polaritydata/rt-polarity.neg', names=['review'],  header=None, encoding='latin-1')
df_p = pd.read_table('/Users/jianwenliu/nlp/rt-polaritydata/rt-polaritydata/rt-polarity.pos', names=['review'],  header=None, encoding='latin-1')
# Out:
# /Users/jianwenliu/anaconda3/envs/deepAI/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
# /Users/jianwenliu/anaconda3/envs/deepAI/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.

# %%
df_n.head(10)
# Out:
#                                               review
# 0                  simplistic , silly and tedious .
# 1  it's so laddish and juvenile , only teenage bo...
# 2  exploitative and largely devoid of the depth o...
# 3  [garbus] discards the potential for pathologic...
# 4  a visually flashy but narratively opaque and e...
# 5  the story is also as unoriginal as they come ,...
# 6  about the only thing to give the movie points ...
# 7                    not so much farcical as sour .
# 8  unfortunately the story and the actors are ser...
# 9  all the more disquieting for its relatively go...

# %%
df_n['lable'] = 0
df_p['lable'] = 1

# %% [markdown]
# shuffle the data and make it to be 50-50 positive and negtive sample. This will make the final metrics accuracy useful

# %%
df = shuffle(pd.concat((df_n, df_p), axis=0), random_state=6)

# %%
df
# Out:
#                                                  review  lable
# 3762  it gives devastating testimony to both people'...      1
# 3932  wanders all over the map thematically and styl...      0
# 1802  it cannot be enjoyed , even on the level that ...      0
# 3211  deliberately and devotedly constructed , far f...      0
# 1172  if the count of monte cristo doesn't transform...      1
# 2559  it's a tour de force , written and directed so...      1
# 519   brady achieves the remarkable feat of squander...      0
# 5182  soulless and -- even more damning -- virtually...      0
# 1067  personal velocity ought to be exploring these ...      0
# 728   [fessenden] is much more into ambiguity and cr...      1
# 5275  a remarkable movie with an unsatisfying ending...      1
# 5189  i suspect that you'll be as bored watching mor...      0
# 650   anchored by a terrific performance by abbass ,...      1
# 398   parker updates the setting in an attempt to ma...      0
# 2146  arnold's jump from little screen to big will l...      0
# 2808   " men in black ii , " has all the earmarks of...      0
# 825   merchant effectively translates naipaul's live...      1
# 1014                                the film is flat .       0
# 3422  weird , vulgar comedy that's definitely an acq...      1
# 3910  there's something fishy about a seasonal holid...      0
# 1654  what could have been a daytime soap opera is a...      1
# 4282  short and sweet , but also more than anything ...      0
# 2053  the film takes too long getting to the good st...      0
# 2012  the vistas are sweeping and the acting is far ...      1
# 1025  a spunky , original take on a theme that will ...      1
# 2937  about a boy vividly recalls the cary grant of ...      1
# 2147  whatever complaints i might have , i'd take [i...      1
# 1886  a compelling yarn , but not quite a ripping on...      1
# 256                           aan opportunity wasted .       0
# 2108  this is a throwaway , junk-food movie whose ra...      0
# ...                                                 ...    ...
# 4207  nicely combines the enigmatic features of 'mem...      1
# 940   the powers team has fashioned a comedy with mo...      1
# 3266  one big blustery movie where nothing really ha...      0
# 4477  a thoughtful , reverent portrait of what is es...      1
# 1899  well-acted , well-directed and , for all its m...      1
# 2692  much of what is meant to be 'inspirational' an...      0
# 222   moore's performance impresses almost as much a...      1
# 4370  with an obvious rapport with her actors and a ...      1
# 5317  a cellophane-pop remake of the punk classic la...      0
# 5035  no amount of burning , blasting , stabbing , a...      0
# 2390  a long-winded and stagy session of romantic co...      0
# 426   whether kiss is a future cult classic or desti...      1
# 1714                                there is truth here      1
# 3916  this is one of the rarest kinds of films : a f...      1
# 5083  nothing but an episode of smackdown ! in perio...      0
# 2252  do not , under any circumstances , consider ta...      0
# 1288  generic slasher-movie nonsense , but it's not ...      0
# 1953  complete lack of originality , cleverness or e...      0
# 2372  this is a particularly toxic little bonbon , p...      0
# 2543  unfortunately , heartbreak hospital wants to c...      0
# 4122  this low-rent -- and even lower-wit -- rip-off...      0
# 1912  brian tufano's handsome widescreen photography...      1
# 70          a taut , intelligent psychological drama .       1
# 1131  it's a much more emotional journey than what s...      1
# 3709  fontaine masterfully creates a portrait of two...      1
# 3196  on its own staggeringly unoriginal terms , thi...      1
# 4714  this is the first film i've ever seen that had...      0
# 4865  the film feels uncomfortably real , its langua...      1
# 3088  about as big a crowdpleaser as they possibly c...      1
# 2761  un thriller manqué qui tombe sur les nerfs pre...      0
#
# [10662 rows x 2 columns]

# %%
df.shape
# Out:
# (10662, 2)

# %% [markdown]
# vectorize the review

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer()
tokenizer.fit_on_texts(df.review)

# %%
sequences = tokenizer.texts_to_sequences(df.review)

# %% [markdown]
# get the max_len, prepare for padding

# %%
max_len = max([len(seq) for seq in sequences])
max_len
# Out:
# 51

# %% [markdown]
# padding

# %%
sequences = pad_sequences(sequences, maxlen=max_len, dtype='int32', padding='pre', truncating='pre', value=0)

# %%
sequences
# Out:
# array([[    0,     0,     0, ...,  2940,    14,    47],
#        [    0,     0,     0, ...,     4,    16,   106],
#        [    0,     0,     0, ...,   275,   848,   275],
#        ...,
#        [    0,     0,     0, ..., 10267,     4,  3092],
#        [    0,     0,     0, ...,    90,  1169,   225],
#        [    0,     0,     0, ...,   718, 19498,  1899]], dtype=int32)

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'a': 2,
#  'and': 3,
#  'of': 4,
#  'to': 5,
#  'is': 6,
#  'in': 7,
#  'that': 8,
#  'it': 9,
#  'as': 10,
#  'but': 11,
#  'with': 12,
#  'film': 13,
#  'for': 14,
#  'this': 15,
#  'its': 16,
#  'an': 17,
#  'movie': 18,
#  "it's": 19,
#  'be': 20,
#  'on': 21,
#  'you': 22,
#  'not': 23,
#  'by': 24,
#  'one': 25,
#  'like': 26,
#  'about': 27,
#  'more': 28,
#  'has': 29,
#  'are': 30,
#  'at': 31,
#  'than': 32,
#  'from': 33,
#  'all': 34,
#  'his': 35,
#  'have': 36,
#  'so': 37,
#  'if': 38,
#  'or': 39,
#  'story': 40,
#  'too': 41,
#  'i': 42,
#  'out': 43,
#  'just': 44,
#  'who': 45,
#  'up': 46,
#  'good': 47,
#  'into': 48,
#  'what': 49,
#  'most': 50,
#  'no': 51,
#  'much': 52,
#  'even': 53,
#  'comedy': 54,
#  'time': 55,
#  'will': 56,
#  'can': 57,
#  'some': 58,
#  'well': 59,
#  'characters': 60,
#  'only': 61,
#  'little': 62,
#  'way': 63,
#  'funny': 64,
#  'their': 65,
#  'director': 66,
#  'make': 67,
#  'been': 68,
#  'your': 69,
#  'enough': 70,
#  'very': 71,
#  'never': 72,
#  'when': 73,
#  'there': 74,
#  'makes': 75,
#  'life': 76,
#  'bad': 77,
#  'may': 78,
#  'which': 79,
#  'best': 80,
#  'us': 81,
#  'work': 82,
#  'he': 83,
#  "doesn't": 84,
#  'love': 85,
#  'any': 86,
#  'would': 87,
#  'made': 88,
#  'while': 89,
#  'they': 90,
#  'we': 91,
#  'was': 92,
#  'new': 93,
#  "there's": 94,
#  'movies': 95,
#  'her': 96,
#  'off': 97,
#  'through': 98,
#  'something': 99,
#  'could': 100,
#  'how': 101,
#  'action': 102,
#  'really': 103,
#  'drama': 104,
#  'two': 105,
#  'own': 106,
#  'them': 107,
#  'see': 108,
#  'performances': 109,
#  'does': 110,
#  "that's": 111,
#  'long': 112,
#  'many': 113,
#  'should': 114,
#  'still': 115,
#  'those': 116,
#  'plot': 117,
#  'look': 118,
#  'every': 119,
#  'films': 120,
#  "isn't": 121,
#  'over': 122,
#  'big': 123,
#  'old': 124,
#  'first': 125,
#  'nothing': 126,
#  'better': 127,
#  'people': 128,
#  'get': 129,
#  'fun': 130,
#  'without': 131,
#  'other': 132,
#  'being': 133,
#  'great': 134,
#  'both': 135,
#  'though': 136,
#  'might': 137,
#  "'": 138,
#  'character': 139,
#  'also': 140,
#  'do': 141,
#  'cast': 142,
#  'another': 143,
#  'real': 144,
#  'audience': 145,
#  'kind': 146,
#  'humor': 147,
#  'ever': 148,
#  'self': 149,
#  'between': 150,
#  'sense': 151,
#  'feel': 152,
#  'such': 153,
#  'less': 154,
#  "don't": 155,
#  'far': 156,
#  'down': 157,
#  'often': 158,
#  'performance': 159,
#  'feels': 160,
#  'few': 161,
#  'hard': 162,
#  'script': 163,
#  'because': 164,
#  "film's": 165,
#  'screen': 166,
#  'world': 167,
#  'here': 168,
#  'thriller': 169,
#  'seems': 170,
#  'thing': 171,
#  'minutes': 172,
#  'tale': 173,
#  'quite': 174,
#  'heart': 175,
#  'full': 176,
#  'picture': 177,
#  'documentary': 178,
#  "can't": 179,
#  'almost': 180,
#  'hollywood': 181,
#  'end': 182,
#  'yet': 183,
#  'interesting': 184,
#  'after': 185,
#  'these': 186,
#  'go': 187,
#  'entertaining': 188,
#  'rather': 189,
#  'my': 190,
#  "you're": 191,
#  'american': 192,
#  'de': 193,
#  'take': 194,
#  'itself': 195,
#  'year': 196,
#  'watching': 197,
#  'seen': 198,
#  'man': 199,
#  'romantic': 200,
#  'ultimately': 201,
#  'family': 202,
#  'moments': 203,
#  'comes': 204,
#  'me': 205,
#  'right': 206,
#  'despite': 207,
#  'lot': 208,
#  'were': 209,
#  'where': 210,
#  'acting': 211,
#  'original': 212,
#  'human': 213,
#  'before': 214,
#  'then': 215,
#  'same': 216,
#  'had': 217,
#  'find': 218,
#  'gets': 219,
#  'worth': 220,
#  'back': 221,
#  'takes': 222,
#  'times': 223,
#  'things': 224,
#  'come': 225,
#  'dialogue': 226,
#  'actors': 227,
#  'scenes': 228,
#  'watch': 229,
#  'high': 230,
#  'compelling': 231,
#  'our': 232,
#  'material': 233,
#  'young': 234,
#  'years': 235,
#  'once': 236,
#  'music': 237,
#  'style': 238,
#  'going': 239,
#  'half': 240,
#  'works': 241,
#  'star': 242,
#  'think': 243,
#  'anyone': 244,
#  'emotional': 245,
#  'seem': 246,
#  'want': 247,
#  'know': 248,
#  'least': 249,
#  'gives': 250,
#  'point': 251,
#  'last': 252,
#  'piece': 253,
#  'special': 254,
#  'making': 255,
#  'give': 256,
#  'say': 257,
#  'kids': 258,
#  'again': 259,
#  'part': 260,
#  'sometimes': 261,
#  'writer': 262,
#  'entertainment': 263,
#  'together': 264,
#  'cinematic': 265,
#  'pretty': 266,
#  "you'll": 267,
#  'moving': 268,
#  'subject': 269,
#  'show': 270,
#  'cinema': 271,
#  'bit': 272,
#  'video': 273,
#  'keep': 274,
#  'dull': 275,
#  'whole': 276,
#  'sweet': 277,
#  'why': 278,
#  'fascinating': 279,
#  'fans': 280,
#  'anything': 281,
#  'war': 282,
#  'true': 283,
#  'art': 284,
#  'away': 285,
#  'age': 286,
#  'since': 287,
#  'manages': 288,
#  'need': 289,
#  'flick': 290,
#  'laughs': 291,
#  'dark': 292,
#  'three': 293,
#  'experience': 294,
#  'history': 295,
#  'always': 296,
#  'clever': 297,
#  'offers': 298,
#  'simply': 299,
#  'direction': 300,
#  'predictable': 301,
#  'silly': 302,
#  'low': 303,
#  'mr': 304,
#  'day': 305,
#  'feature': 306,
#  'comic': 307,
#  'instead': 308,
#  'care': 309,
#  'actually': 310,
#  'him': 311,
#  'whose': 312,
#  'coming': 313,
#  'done': 314,
#  'nearly': 315,
#  'around': 316,
#  'charm': 317,
#  'visual': 318,
#  'matter': 319,
#  'everything': 320,
#  'under': 321,
#  'title': 322,
#  'horror': 323,
#  'place': 324,
#  'series': 325,
#  'looking': 326,
#  'familiar': 327,
#  'narrative': 328,
#  'idea': 329,
#  'short': 330,
#  'set': 331,
#  'genre': 332,
#  "he's": 333,
#  'effects': 334,
#  'goes': 335,
#  'mind': 336,
#  'now': 337,
#  'trying': 338,
#  'screenplay': 339,
#  "movie's": 340,
#  'women': 341,
#  'smart': 342,
#  'probably': 343,
#  'plays': 344,
#  'power': 345,
#  'home': 346,
#  'hour': 347,
#  'premise': 348,
#  'turns': 349,
#  'she': 350,
#  'thought': 351,
#  'enjoyable': 352,
#  'lacks': 353,
#  'although': 354,
#  'engaging': 355,
#  'becomes': 356,
#  'feeling': 357,
#  'filmmakers': 358,
#  "won't": 359,
#  'study': 360,
#  'worst': 361,
#  'especially': 362,
#  'ending': 363,
#  'strong': 364,
#  'enjoy': 365,
#  'amusing': 366,
#  'effort': 367,
#  'minute': 368,
#  'likely': 369,
#  'modern': 370,
#  'intelligent': 371,
#  'charming': 372,
#  'romance': 373,
#  'lack': 374,
#  'directed': 375,
#  'men': 376,
#  'debut': 377,
#  'acted': 378,
#  'tv': 379,
#  'theater': 380,
#  'put': 381,
#  'solid': 382,
#  'boring': 383,
#  'john': 384,
#  'face': 385,
#  'else': 386,
#  'mostly': 387,
#  'portrait': 388,
#  'fresh': 389,
#  'each': 390,
#  'message': 391,
#  'girl': 392,
#  'version': 393,
#  'hours': 394,
#  'wit': 395,
#  'beautiful': 396,
#  'certainly': 397,
#  'shot': 398,
#  'sort': 399,
#  'easy': 400,
#  "what's": 401,
#  'level': 402,
#  'black': 403,
#  'next': 404,
#  'heavy': 405,
#  'play': 406,
#  'serious': 407,
#  'fine': 408,
#  "you've": 409,
#  'surprisingly': 410,
#  'become': 411,
#  'beautifully': 412,
#  'lives': 413,
#  'exercise': 414,
#  'quirky': 415,
#  'small': 416,
#  'slow': 417,
#  'interest': 418,
#  'french': 419,
#  'sure': 420,
#  'light': 421,
#  'rare': 422,
#  'along': 423,
#  'energy': 424,
#  'problem': 425,
#  'beyond': 426,
#  'leave': 427,
#  'powerful': 428,
#  'obvious': 429,
#  'looks': 430,
#  'mess': 431,
#  'whether': 432,
#  'ideas': 433,
#  'opera': 434,
#  'completely': 435,
#  'past': 436,
#  'fact': 437,
#  'melodrama': 438,
#  'culture': 439,
#  'must': 440,
#  'dramatic': 441,
#  'either': 442,
#  'adventure': 443,
#  'tone': 444,
#  'reason': 445,
#  'classic': 446,
#  'viewers': 447,
#  'believe': 448,
#  'children': 449,
#  'neither': 450,
#  'book': 451,
#  'actor': 452,
#  'written': 453,
#  'shows': 454,
#  'jokes': 455,
#  'stuff': 456,
#  'sex': 457,
#  'delivers': 458,
#  'live': 459,
#  'recent': 460,
#  'filmmaking': 461,
#  "didn't": 462,
#  'fails': 463,
#  'death': 464,
#  'suspense': 465,
#  "i'm": 466,
#  'school': 467,
#  'scene': 468,
#  'left': 469,
#  'camera': 470,
#  'everyone': 471,
#  'tries': 472,
#  'deeply': 473,
#  'production': 474,
#  'truly': 475,
#  'intriguing': 476,
#  'perfect': 477,
#  'himself': 478,
#  'ends': 479,
#  'middle': 480,
#  'laugh': 481,
#  'ride': 482,
#  'above': 483,
#  'sad': 484,
#  'simple': 485,
#  'close': 486,
#  'head': 487,
#  'spirit': 488,
#  'exactly': 489,
#  'line': 490,
#  'touching': 491,
#  'reality': 492,
#  'dumb': 493,
#  'hilarious': 494,
#  'occasionally': 495,
#  'impossible': 496,
#  'audiences': 497,
#  'terrific': 498,
#  'formula': 499,
#  'remains': 500,
#  'storytelling': 501,
#  'role': 502,
#  'already': 503,
#  'proves': 504,
#  'spy': 505,
#  'satisfying': 506,
#  'passion': 507,
#  'pleasure': 508,
#  'summer': 509,
#  'b': 510,
#  'teen': 511,
#  'project': 512,
#  'dead': 513,
#  'crime': 514,
#  'different': 515,
#  'got': 516,
#  'images': 517,
#  'stories': 518,
#  'talent': 519,
#  'filmmaker': 520,
#  'seeing': 521,
#  'nor': 522,
#  'personal': 523,
#  'attempt': 524,
#  'sequel': 525,
#  'flat': 526,
#  'turn': 527,
#  'journey': 528,
#  'political': 529,
#  'gags': 530,
#  'side': 531,
#  'run': 532,
#  'easily': 533,
#  'particularly': 534,
#  'boy': 535,
#  'honest': 536,
#  'difficult': 537,
#  'pretentious': 538,
#  'given': 539,
#  'complex': 540,
#  'against': 541,
#  'mystery': 542,
#  'animation': 543,
#  'psychological': 544,
#  'earnest': 545,
#  'found': 546,
#  'thin': 547,
#  'did': 548,
#  'intelligence': 549,
#  'second': 550,
#  'ways': 551,
#  'eye': 552,
#  'stand': 553,
#  'visually': 554,
#  'falls': 555,
#  'cold': 556,
#  'social': 557,
#  'none': 558,
#  'case': 559,
#  'michael': 560,
#  'cool': 561,
#  'class': 562,
#  'game': 563,
#  'getting': 564,
#  'told': 565,
#  'tell': 566,
#  'gone': 567,
#  'hit': 568,
#  'leaves': 569,
#  'straight': 570,
#  'cliches': 571,
#  'uses': 572,
#  'que': 573,
#  'violence': 574,
#  'memorable': 575,
#  'writing': 576,
#  'top': 577,
#  'help': 578,
#  'budget': 579,
#  'brilliant': 580,
#  'soap': 581,
#  'overall': 582,
#  'act': 583,
#  'wrong': 584,
#  'finally': 585,
#  'job': 586,
#  'four': 587,
#  'rich': 588,
#  'concept': 589,
#  'truth': 590,
#  'rock': 591,
#  'keeps': 592,
#  'satire': 593,
#  'novel': 594,
#  'nature': 595,
#  'elements': 596,
#  '2': 597,
#  'warm': 598,
#  'barely': 599,
#  'o': 600,
#  'days': 601,
#  'creepy': 602,
#  'otherwise': 603,
#  'rarely': 604,
#  'needs': 605,
#  'deep': 606,
#  'lost': 607,
#  'contrived': 608,
#  'guys': 609,
#  'mood': 610,
#  'taste': 611,
#  'wild': 612,
#  'fi': 613,
#  'starts': 614,
#  'entirely': 615,
#  'y': 616,
#  'final': 617,
#  'important': 618,
#  'form': 619,
#  'running': 620,
#  'worthy': 621,
#  'imagine': 622,
#  'thoughtful': 623,
#  'during': 624,
#  'appeal': 625,
#  'moral': 626,
#  'several': 627,
#  'approach': 628,
#  'possible': 629,
#  'having': 630,
#  'disney': 631,
#  'clear': 632,
#  'eyes': 633,
#  'animated': 634,
#  'sci': 635,
#  'future': 636,
#  'wonderful': 637,
#  'excellent': 638,
#  'call': 639,
#  'tragedy': 640,
#  "they're": 641,
#  'behind': 642,
#  'city': 643,
#  'based': 644,
#  'adults': 645,
#  '\x96': 646,
#  'loud': 647,
#  'surprising': 648,
#  'lead': 649,
#  'fairly': 650,
#  'insight': 651,
#  'oscar': 652,
#  'attention': 653,
#  'fire': 654,
#  'perhaps': 655,
#  'remarkable': 656,
#  'moment': 657,
#  'entire': 658,
#  'david': 659,
#  'bland': 660,
#  'thoroughly': 661,
#  'period': 662,
#  'tedious': 663,
#  'engrossing': 664,
#  'others': 665,
#  'comedies': 666,
#  'epic': 667,
#  'themselves': 668,
#  'quality': 669,
#  'imagination': 670,
#  'hero': 671,
#  'viewer': 672,
#  'cute': 673,
#  'change': 674,
#  'witty': 675,
#  'among': 676,
#  'depth': 677,
#  'bring': 678,
#  'woman': 679,
#  'expect': 680,
#  'result': 681,
#  'start': 682,
#  'fantasy': 683,
#  'knows': 684,
#  'air': 685,
#  'co': 686,
#  'career': 687,
#  'genuine': 688,
#  'taking': 689,
#  'filled': 690,
#  'strange': 691,
#  'maybe': 692,
#  'latest': 693,
#  'emotionally': 694,
#  'single': 695,
#  'wonder': 696,
#  'cut': 697,
#  "i've": 698,
#  'remake': 699,
#  'sharp': 700,
#  'vision': 701,
#  'gorgeous': 702,
#  'road': 703,
#  'house': 704,
#  'merely': 705,
#  'quiet': 706,
#  'fast': 707,
#  'nice': 708,
#  'tired': 709,
#  'perfectly': 710,
#  'adaptation': 711,
#  "you'd": 712,
#  'working': 713,
#  'add': 714,
#  'hand': 715,
#  'usual': 716,
#  'pop': 717,
#  'la': 718,
#  'white': 719,
#  'ii': 720,
#  'gentle': 721,
#  'begins': 722,
#  'impressive': 723,
#  'guy': 724,
#  'ugly': 725,
#  'until': 726,
#  'cheap': 727,
#  'hope': 728,
#  'joke': 729,
#  'points': 730,
#  'winning': 731,
#  'effective': 732,
#  'plenty': 733,
#  'decent': 734,
#  'surprise': 735,
#  'beauty': 736,
#  'thanks': 737,
#  'stupid': 738,
#  'worse': 739,
#  'offer': 740,
#  'parents': 741,
#  'doing': 742,
#  'view': 743,
#  'somewhat': 744,
#  'events': 745,
#  'scary': 746,
#  'cultural': 747,
#  'appealing': 748,
#  'definitely': 749,
#  'sit': 750,
#  'however': 751,
#  'playing': 752,
#  'someone': 753,
#  'inside': 754,
#  'ambitious': 755,
#  'try': 756,
#  'lots': 757,
#  'awful': 758,
#  'magic': 759,
#  'able': 760,
#  'water': 761,
#  'provides': 762,
#  'unfortunately': 763,
#  'captures': 764,
#  'emotions': 765,
#  'pure': 766,
#  'mean': 767,
#  'miss': 768,
#  "year's": 769,
#  'highly': 770,
#  'force': 771,
#  'free': 772,
#  'night': 773,
#  'exciting': 774,
#  'open': 775,
#  'pace': 776,
#  'major': 777,
#  'throughout': 778,
#  'crafted': 779,
#  'sound': 780,
#  'execution': 781,
#  'examination': 782,
#  'female': 783,
#  'subtle': 784,
#  'historical': 785,
#  'welcome': 786,
#  'sequences': 787,
#  'robert': 788,
#  'utterly': 789,
#  'stars': 790,
#  'suffers': 791,
#  'hip': 792,
#  'pictures': 793,
#  'brings': 794,
#  '90': 795,
#  'soul': 796,
#  'memory': 797,
#  'numbers': 798,
#  'lovely': 799,
#  'college': 800,
#  'sustain': 801,
#  'process': 802,
#  'relationship': 803,
#  'hell': 804,
#  'fashioned': 805,
#  'sexual': 806,
#  'creative': 807,
#  'read': 808,
#  'deserves': 809,
#  'meaning': 810,
#  'alone': 811,
#  'certain': 812,
#  'murder': 813,
#  'provocative': 814,
#  'ensemble': 815,
#  'felt': 816,
#  'ago': 817,
#  'dog': 818,
#  'average': 819,
#  'bond': 820,
#  'words': 821,
#  'cartoon': 822,
#  'length': 823,
#  'deal': 824,
#  'tension': 825,
#  'delightful': 826,
#  'except': 827,
#  'quickly': 828,
#  'potential': 829,
#  'use': 830,
#  'country': 831,
#  'creates': 832,
#  'paced': 833,
#  'e': 834,
#  'era': 835,
#  'impact': 836,
#  'poignant': 837,
#  'wants': 838,
#  'question': 839,
#  'across': 840,
#  'chemistry': 841,
#  'actress': 842,
#  'flaws': 843,
#  'upon': 844,
#  'odd': 845,
#  'ya': 846,
#  'used': 847,
#  'yes': 848,
#  'situation': 849,
#  'create': 850,
#  'handed': 851,
#  'sensitive': 852,
#  'trip': 853,
#  'formulaic': 854,
#  'master': 855,
#  'waste': 856,
#  'rest': 857,
#  'date': 858,
#  'contemporary': 859,
#  'unexpected': 860,
#  'puts': 861,
#  'sentimental': 862,
#  'talented': 863,
#  'money': 864,
#  'casting': 865,
#  'generic': 866,
#  'unfunny': 867,
#  'five': 868,
#  'taken': 869,
#  'success': 870,
#  'flawed': 871,
#  't': 872,
#  'unsettling': 873,
#  'happy': 874,
#  'lacking': 875,
#  'called': 876,
#  'issues': 877,
#  'extreme': 878,
#  'mediocre': 879,
#  'touch': 880,
#  'cannot': 881,
#  'fully': 882,
#  'mix': 883,
#  'weird': 884,
#  'convincing': 885,
#  'grant': 886,
#  'reveals': 887,
#  'saw': 888,
#  'hold': 889,
#  'hardly': 890,
#  "aren't": 891,
#  'slightly': 892,
#  'trouble': 893,
#  'previous': 894,
#  'supposed': 895,
#  'remember': 896,
#  'focus': 897,
#  'mark': 898,
#  'routine': 899,
#  's': 900,
#  'course': 901,
#  'giving': 902,
#  'leads': 903,
#  'crowd': 904,
#  'ability': 905,
#  'artist': 906,
#  'thinking': 907,
#  'sincere': 908,
#  'badly': 909,
#  'inspired': 910,
#  'extremely': 911,
#  'key': 912,
#  'relationships': 913,
#  'urban': 914,
#  'forgettable': 915,
#  'boys': 916,
#  'large': 917,
#  'surprises': 918,
#  'involved': 919,
#  'apart': 920,
#  'episode': 921,
#  'masterpiece': 922,
#  'seriously': 923,
#  'melodramatic': 924,
#  'mildly': 925,
#  'grace': 926,
#  'watchable': 927,
#  'ultimate': 928,
#  'living': 929,
#  'thrills': 930,
#  'tragic': 931,
#  'room': 932,
#  'kid': 933,
#  'indeed': 934,
#  'ones': 935,
#  'uneven': 936,
#  'largely': 937,
#  'plain': 938,
#  'intimate': 939,
#  'couple': 940,
#  'succeeds': 941,
#  'yourself': 942,
#  'amount': 943,
#  'monster': 944,
#  'crazy': 945,
#  'gross': 946,
#  'sets': 947,
#  'century': 948,
#  'dry': 949,
#  'stylish': 950,
#  'george': 951,
#  'attempts': 952,
#  'slight': 953,
#  'name': 954,
#  'inventive': 955,
#  'finds': 956,
#  'treat': 957,
#  'ill': 958,
#  'crush': 959,
#  'pacing': 960,
#  'steven': 961,
#  'substance': 962,
#  'terms': 963,
#  'twists': 964,
#  'provoking': 965,
#  'pleasant': 966,
#  'gripping': 967,
#  'heaven': 968,
#  'near': 969,
#  'painful': 970,
#  'soundtrack': 971,
#  'flicks': 972,
#  'runs': 973,
#  'poetry': 974,
#  'fiction': 975,
#  'cross': 976,
#  'viewing': 977,
#  'successful': 978,
#  'es': 979,
#  'television': 980,
#  'promise': 981,
#  'appears': 982,
#  'presents': 983,
#  'complete': 984,
#  'interested': 985,
#  'sports': 986,
#  'hits': 987,
#  'skin': 988,
#  'played': 989,
#  'york': 990,
#  'person': 991,
#  'williams': 992,
#  'meditation': 993,
#  '10': 994,
#  'unique': 995,
#  'themes': 996,
#  'goofy': 997,
#  'happens': 998,
#  'standard': 999,
#  'lame': 1000,
#  ...}

# %%
voc_size=len(tokenizer.word_index)

# %%
voc_size
# Out:
# 19498

# %% [markdown]
# # RNN (LSTM) model for Text Classification

# %% [markdown]
# build the LSTM model

# %%
# model where N=1, M=1 and K=1
def bilstm_model(output_dim=64, dense_dim=16):
    
    #input and embedding
    input = Input(shape=(max_len,), dtype='float64')
    embed = Embedding(voc_size+1, output_dim, input_length=max_len, embeddings_initializer='random_uniform')(input)
    
    #bi-lstm layer
    lstm = Bidirectional(LSTM(units=100, return_sequences=True))(embed)
    
    
    #flatten and dense layer
    lstm = Flatten()(lstm)
    dense = Dense(dense_dim, activation='relu')(lstm)
    
    #Dropout
    dense = Dropout(0.5)(dense)
    
    output = Dense(1, kernel_regularizer=regularizers.l2(0.03),activity_regularizer=regularizers.l1(0.01),activation='sigmoid')(lstm)
    
    model = Model(input, output)
    
    ##use rmsprop
    model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    
    return model
    
bilstm_model().summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 51)                0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 51, 64)            1247936
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 51, 200)           132000
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10200)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 10201
# =================================================================
# Total params: 1,390,137
# Trainable params: 1,390,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 10
BATCH_SIZE = 128
fold = 8

model = bilstm_model()
X = sequences
y = np.array(df.lable.tolist())

# %% [markdown]
# # Model performance : prediction accuracy

# %%
kfold = StratifiedKFold(n_splits=fold, shuffle=True, random_state=7)

# %%
acr = list()
i = 0
for train_index, valid_index in kfold.split(X, y):
    i += 1
    X_train, X_valid = X[train_index], X[valid_index]
    y_train, y_valid = y[train_index], y[valid_index]
    model = bilstm_model()
    model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=2, validation_data=(X_valid, y_valid),\
              callbacks=[EarlyStopping(patience=1, monitor='val_loss')])
    y_hat = model.predict(X_valid)
    y_pred = [round(pred) for pred in y_hat.reshape(-1)]
    acr.append(accuracy_score(y_valid, y_pred))
# Out:
# Train on 9328 samples, validate on 1334 samples
# Epoch 1/10
#  - 39s - loss: 1.1655 - acc: 0.5123 - val_loss: 1.1169 - val_acc: 0.6319
# Epoch 2/10
#  - 30s - loss: 0.9600 - acc: 0.7363 - val_loss: 1.0558 - val_acc: 0.7609
# Epoch 3/10
#  - 30s - loss: 0.8617 - acc: 0.8310 - val_loss: 1.0812 - val_acc: 0.7346
# Train on 9328 samples, validate on 1334 samples
# Epoch 1/10
#  - 39s - loss: 1.1629 - acc: 0.5163 - val_loss: 1.1038 - val_acc: 0.5585
# Epoch 2/10
#  - 33s - loss: 0.9685 - acc: 0.7347 - val_loss: 1.0089 - val_acc: 0.7159
# Epoch 3/10
#  - 43s - loss: 0.8597 - acc: 0.8336 - val_loss: 1.0832 - val_acc: 0.7436
# Train on 9328 samples, validate on 1334 samples
# Epoch 1/10
#  - 37s - loss: 1.1662 - acc: 0.5090 - val_loss: 1.0634 - val_acc: 0.5210
# Epoch 2/10
#  - 28s - loss: 0.9703 - acc: 0.7230 - val_loss: 0.9933 - val_acc: 0.6582
# Epoch 3/10
#  - 28s - loss: 0.8643 - acc: 0.8243 - val_loss: 1.0483 - val_acc: 0.7054
# Train on 9330 samples, validate on 1332 samples
# Epoch 1/10
#  - 36s - loss: 1.1636 - acc: 0.5096 - val_loss: 1.1291 - val_acc: 0.6404
# Epoch 2/10
#  - 27s - loss: 0.9647 - acc: 0.7317 - val_loss: 1.0562 - val_acc: 0.7432
# Epoch 3/10
#  - 26s - loss: 0.8545 - acc: 0.8299 - val_loss: 1.0943 - val_acc: 0.7372
# Train on 9330 samples, validate on 1332 samples
# Epoch 1/10
#  - 33s - loss: 1.1624 - acc: 0.5077 - val_loss: 1.0305 - val_acc: 0.6569
# Epoch 2/10
#  - 27s - loss: 0.9656 - acc: 0.7243 - val_loss: 0.9943 - val_acc: 0.7200
# Epoch 3/10
#  - 35s - loss: 0.8622 - acc: 0.8263 - val_loss: 0.9982 - val_acc: 0.7357
# Train on 9330 samples, validate on 1332 samples
# Epoch 1/10
#  - 51s - loss: 1.1667 - acc: 0.5124 - val_loss: 1.1051 - val_acc: 0.6539
# Epoch 2/10
#  - 31s - loss: 0.9683 - acc: 0.7414 - val_loss: 1.0014 - val_acc: 0.7095
# Epoch 3/10
#  - 31s - loss: 0.8585 - acc: 0.8338 - val_loss: 1.0191 - val_acc: 0.7275
# Train on 9330 samples, validate on 1332 samples
# Epoch 1/10
#  - 41s - loss: 1.1648 - acc: 0.5109 - val_loss: 1.1427 - val_acc: 0.6712
# Epoch 2/10
#  - 31s - loss: 0.9792 - acc: 0.7202 - val_loss: 1.0421 - val_acc: 0.7327
# Epoch 3/10
#  - 31s - loss: 0.8643 - acc: 0.8282 - val_loss: 1.1602 - val_acc: 0.7057
# Train on 9330 samples, validate on 1332 samples
# Epoch 1/10
#  - 40s - loss: 1.1542 - acc: 0.5164 - val_loss: 1.1183 - val_acc: 0.5976
# Epoch 2/10
#  - 34s - loss: 0.9581 - acc: 0.7362 - val_loss: 0.9920 - val_acc: 0.7200
# Epoch 3/10
#  - 34s - loss: 0.8602 - acc: 0.8322 - val_loss: 1.0129 - val_acc: 0.7327

# %%
print('Average accuracy ', np.mean(np.array(acr)))
# Out:
# Average accuracy  0.727818382475429

# %% [markdown]
# # Conclusion

# %% [markdown]
# By comparing the RNN and CNN model, we can find out there are at least two main conclusions: Firstly, the training complexity for RNN is much less than CNN. This means RNN is a much faster architecture than CNN. The average ecpoch time for RNN is about 35s, while the average ecpoch time for CNN is about 110s.<br><br>
# Secondly, According to the performance, which is the accuracy of model, we can also find out that CNN has a little higher accuracy than RNN (0.74 to 0.72). This indicates that RNN may be less accurate then CNN for some dataset. Even though CNN is essentialy a N-gram based model, it still works for NLP task.<br><br>
# Therefore, in NLP task, RNN may be a preference than CNN for its efficiency, while CNN also works. A good application of CNN is to aggregate the Character information for words.
